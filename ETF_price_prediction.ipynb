# %%
import pandas as pd
import numpy as np
from FundInfo import FundPricePrediction
import seaborn as sns
from matplotlib import pyplot as plt
from datetime import datetime

# %matplotlib inline

# %%
startDate = "2018-01-01"
endDate = datetime.today().strftime('%Y-%m-%d')

fundValues = FundPricePrediction("VCN", startDate, endDate)
# Out:
# Training samples: 449
# Validation samples: 193
# C:\Users\raja\Documents\pythonprojects\etfanalysis\FundInfo.py:361: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   priceDF["date"] = pd.to_datetime(priceDF["date"],format="%Y-%m-%d")

# %%
fundValues.predictRegression("linear")

# %%
fundValues.predictRegression("ridge")

# %%
fundValues.predictRegression("lasso")

# %%
fundValues.predictRegression("arima")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-0a8d3c12fd57> in <module>
# ----> 1 fundValues.predictRegression("arima")
#
# NameError: name 'fundValues' is not defined
