# %%
import pandas as pd
import numpy as np
from FundInfo import FundPricePrediction
import seaborn as sns
from matplotlib import pyplot as plt
from datetime import datetime

# %matplotlib inline

# %%
startDate = "2018-01-01"
endDate = datetime.today().strftime('%Y-%m-%d')

fundValues = FundPricePrediction("VCN", startDate, endDate)
# Out:
# Training samples: 456
# Validation samples: 196
# C:\Users\raja\Documents\pythonprojects\etfanalysis\FundInfo.py:369: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   priceDF["date"] = pd.to_datetime(priceDF["date"],format="%Y-%m-%d")

# %%
fundValues.predictRegression("linear")

# %%
fundValues.predictRegression("ridge")

# %%
fundValues.predictRegression("lasso")

# %%
fundValues.predictRegression("arima")
# Out:
# Performing stepwise search to minimize aic
# Fit ARIMA(1,1,1)x(0,1,1,12) [intercept=True]; AIC=-157.003, BIC=-136.535, Time=4.874 seconds
# Fit ARIMA(0,1,0)x(0,1,0,12) [intercept=True]; AIC=126.329, BIC=134.516, Time=0.223 seconds
# Fit ARIMA(1,1,0)x(1,1,0,12) [intercept=True]; AIC=-33.874, BIC=-17.500, Time=1.653 seconds
# Fit ARIMA(0,1,1)x(0,1,1,12) [intercept=True]; AIC=-158.980, BIC=-142.605, Time=5.531 seconds
# Near non-invertible roots for order (0, 1, 1)(0, 1, 1, 12); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.997)
# Fit ARIMA(0,1,0)x(0,1,0,12) [intercept=False]; AIC=124.329, BIC=128.422, Time=0.109 seconds
# Fit ARIMA(1,1,1)x(0,1,0,12) [intercept=True]; AIC=127.454, BIC=143.828, Time=1.167 seconds
# Fit ARIMA(1,1,1)x(1,1,1,12) [intercept=True]; AIC=-156.225, BIC=-131.664, Time=4.095 seconds
# ...

# %%
fundValues.predictNN(option="lstm")
# Out:
# Epoch :1
# Epoch train loss is 221.4584
# Epoch validation loss is 90.7671
# Validation loss decreased(10000.000000 --> 90.767113).  Saving model ...
# 0m 4s
# Epoch :2
# Epoch train loss is 148.8846
# Epoch validation loss is 63.3681
# Validation loss decreased(90.767113 --> 63.368080).  Saving model ...
# 0m 2s
# Epoch :3
# Epoch train loss is 80.3698
# Epoch validation loss is 38.8126
# Validation loss decreased(63.368080 --> 38.812641).  Saving model ...
# 0m 2s
# Epoch :4
# Epoch train loss is 19.3424
# Epoch validation loss is 65.8730
# 0m 2s
# Epoch :5
# Epoch train loss is 83.3561
# Epoch validation loss is 42.2400
# 0m 2s
# Epoch :6
# Epoch train loss is 27.3139
# Epoch validation loss is 36.4319
# Validation loss decreased(38.812641 --> 36.431911).  Saving model ...
# 0m 2s
# Epoch :7
# Epoch train loss is 13.4924
# Epoch validation loss is 41.2086
# 0m 2s
# Epoch :8
# Epoch train loss is 25.9800
# Epoch validation loss is 45.3991
# 0m 2s
# Epoch :9
# ...
